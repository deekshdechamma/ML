# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\deeks\OneDrive\Desktop\My Folder\archive (6)\loan_approval_dataset.csv")

# %%
df.shape
# Out:
# (4269, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# memory usage: 433.7+ KB

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %%
df.columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' education', ' self_employed',
#        ' income_annum', ' loan_amount', ' loan_term', ' cibil_score',
#        ' residential_assets_value', ' commercial_assets_value',
#        ' luxury_assets_value', ' bank_asset_value', ' loan_status'],
#       dtype='object')

# %%
df[' education'].unique()
# Out:
# array([' Graduate', ' Not Graduate'], dtype=object)

# %%
df[' education'].value_counts()
# Out:
#  education
# Graduate        2144
# Not Graduate    2125
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df[' education'] = le.fit_transform(df[' education'])

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   education  self_employed   income_annum  \
# 0        1                  2           0             No        9600000
# 1        2                  0           1            Yes        4100000
# 2        3                  3           0             No        9100000
# 3        4                  3           0             No        8200000
# 4        5                  5           1            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df[' self_employed'] = pd.get_dummies(df[' self_employed'],drop_first=True)

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   education   self_employed   income_annum  \
# 0        1                  2           0           False        9600000
# 1        2                  0           1            True        4100000
# 2        3                  3           0           False        9100000
# 3        4                  3           0           False        8200000
# 4        5                  5           1            True        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df = pd.get_dummies(df, columns = [' self_employed'])

# %%
df.head()
# Out:
#    loan_id   no_of_dependents   education   income_annum   loan_amount  \
# 0        1                  2           0        9600000      29900000
# 1        2                  0           1        4100000      12200000
# 2        3                  3           0        9100000      29700000
# 3        4                  3           0        8200000      30700000
# 4        5                  5           1        9800000      24200000
#
#     loan_term   cibil_score   residential_assets_value  \
# 0          12           778                    2400000
# 1           8           417                    2700000
# 2          20           506                    7100000
# 3           8           467                   18200000
# 4          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status   self_employed_False   self_employed_True
# 0     Approved                  True                False
# 1     Rejected                 False                 True
# 2     Rejected                  True                False
# 3     Rejected                  True                False
# 4     Rejected                 False                 True

# %%
from sklearn.preprocessing import LabelEncoder

df.columns = df.columns.str.strip()

le = LabelEncoder()

cat_cols = ['education']   

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    loan_id  no_of_dependents  education  income_annum  loan_amount  loan_term  \
# 0        1                 2          0       9600000     29900000         12
# 1        2                 0          1       4100000     12200000          8
# 2        3                 3          0       9100000     29700000         20
# 3        4                 3          0       8200000     30700000          8
# 4        5                 5          1       9800000     24200000         20
#
#    cibil_score  residential_assets_value  commercial_assets_value  \
# 0          778                   2400000                 17600000
# 1          417                   2700000                  2200000
# 2          506                   7100000                  4500000
# 3          467                  18200000                  3300000
# 4          382                  12400000                  8200000
#
#    luxury_assets_value  bank_asset_value loan_status  self_employed_False  \
# 0             22700000           8000000    Approved                 True
# 1              8800000           3300000    Rejected                False
# 2             33300000          12800000    Rejected                 True
# 3             23300000           7900000    Rejected                 True
# 4             29400000           5000000    Rejected                False
#
#    self_employed_True
# 0               False
# 1                True
# 2               False
# 3               False
# 4                True

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

df.columns = df.columns.str.strip()

dtc = DecisionTreeClassifier(max_depth=4, random_state=50)

X = df.drop(columns=['loan_status'])
Y = df['loan_status']

X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42
)

# %%
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, random_state=50)

# %%
Y_pred = dtc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy score:", accuracy_score(Y_test, Y_pred))
print("Classification Report:\n", classification_report(Y_test, Y_pred))
# Out:
# Accuracy score: 0.9617486338797814
# Classification Report:
#                precision    recall  f1-score   support
#
#     Approved       0.95      1.00      0.97       810
#     Rejected       1.00      0.90      0.95       471
#
#     accuracy                           0.96      1281
#    macro avg       0.97      0.95      0.96      1281
# weighted avg       0.96      0.96      0.96      1281

# %%
from sklearn import tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

tree.plot_tree(
    dtc,
    feature_names=X.columns,
    class_names=['Approved', 'Rejected'],  
    filled=True
)

plt.show()
