# %%
x = [_for _ in range(10)]
y = [_*3+5 for _ in X]
print(X)
print(y)
# Out:
#   Cell In[1], line 1
#     x = [_for _ in range(10)]
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import numpy as np
import matplotlib.pyplot as plt
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)
plt.scatter(X,y)
plt.show()
